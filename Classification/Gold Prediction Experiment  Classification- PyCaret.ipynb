# %% [markdown]
# # Predicting return from Gold

# %% [markdown]
# ## Importing and Preparing Data

# %% [markdown]
# For this and subsequent exercises we will need closing price of several instruments for past 10 years . There are various paid (Reuters, Bloomberg) and free resources (IEX, Quandl, Yahoofinance, Google finance) that we can use to either extract and load data in csv or we can directly call their APIs. Since in this project I needed different type of asset classes (Equities, Commodities, Debt and precious metals) I found the 'yahoofinancials' package to be very helpful and straight forward. (https://pypi.org/project/yahoofinancials/)

# %% [markdown]
# ### Installing Libraries

# %%
#pip install pycaret

# %%
#pip install yahoofinancials

# %% [raw]
# #### Only if you are running this on google colab
# from pycaret.utils import enable_colab
# enable_colab()

# %%
#Importing Libraries
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from yahoofinancials import YahooFinancials
import numpy as np

# %% [markdown]
# #### Only if you are running this on google colab to load Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# I have prepared a list instruments for which we need to import data. yahoofinancials package requires Yahoo ticker symbols. The list contains the ticker symbols and their descriptions. The excel file containing the list can be found here..... We import that file and extract the tciker symbols and the names as seprarate lists

# %%
ticker_details = pd.read_excel(r"C:\Users\Arun Sabarish\Documents\GitHub\Gold-Return-Prediction\Ticker List.xlsx")
ticker_details.head(20)
# Out:
#       Ticker              Description
# 0       GC=F                     Gold
# 1       SI=F                   Silver
# 2       CL=F                Crude Oil
# 3      ^GSPC                   S&P500
# 4       ^RUT        Russel 2000 Index
# 5       ZN=F  10 Yr US T-Note futures
# 6       ZT=F   2 Yr US T-Note Futures
# 7       PL=F                 Platinum
# 8       HG=F                   Copper
# 9       DX=F             Dollar Index
# 10      ^VIX         Volatility Index
# 11       S=F                  Soybean
# 12       EEM              MSCI EM ETF
# 13  EURUSD=X                 Euro USD
# 14     ^N100              Euronext100
# 15     ^IXIC                   Nasdaq

# %%
ticker = ticker_details['Ticker'].to_list()
names = ticker_details['Description'].to_list()

# %% [markdown]
# Once we have the list, we need to define what date range we need to import the data for. The period I have chosen is Jan 2010 till 1st Mar 2020. The reason I did not pull data prior to that is because the GFC in 2008-09 massively changed the economic and market landscapes. Relationships pririo to that peirod might be of less relevance now. We also dont want to feed very less data as the models might tend to overfit.
#
# We create a date-range and write it to an empty dataframe named values where we would extract and past the values we pull from yahoofinancials.

# %%
#Extracting Data from Yahoo Finance and Adding them to Values table using date as key
end_date= "2020-08-01"
start_date = "2010-01-01"
date_range = pd.bdate_range(start=start_date,end=end_date)
values = pd.DataFrame({ 'Date': date_range})
values['Date']= pd.to_datetime(values['Date'])

# %% [markdown]
# Once we have the date range in dataframe, we need to use ticker symbols to pull out data from the API. yahoofinancials returns the output in a JSON format. The following code loops over the the list of ticker symbols and extracts just the closing prices for all the historical dates and keeps them adding to the dataframe horizontally. Note I have used the merge function to mantain the sanctity of dates. Given these asset classes might have different regional and trading holidays, the date ranges are not bound to be the same. By merging, we will eventually have several NAs which we will frontfill later on.

# %%
#Extracting Data from Yahoo Finance and Adding them to Values table using date as key
for i in ticker:
    raw_data = YahooFinancials(i)
    raw_data = raw_data.get_historical_price_data(start_date, end_date, "daily")
    df = pd.DataFrame(raw_data[i]['prices'])[['formatted_date','adjclose']]
    df.columns = ['Date1',i]
    df['Date1']= pd.to_datetime(df['Date1'])
    values = values.merge(df,how='left',left_on='Date',right_on='Date1')
    values = values.drop(labels='Date1',axis=1)

#Renaming columns to represent instrument names rather than their ticker codes for ease of readability
names.insert(0,'Date')
values.columns = names
print(values.shape)
print(values.isna().sum())
values.tail()
# Out:
# (2761, 17)
# Date                         0
# Gold                       120
# Silver                     120
# Crude Oil                  119
# S&P500                      98
# Russel 2000 Index           98
# 10 Yr US T-Note futures    121
# 2 Yr US T-Note Futures     119
# Platinum                   120
# Copper                     120
# Dollar Index               121
# Volatility Index            98
# Soybean                    119
# MSCI EM ETF                 98
# Euro USD                   329
# Euronext100                 58
# Nasdaq                      98
# dtype: int64
#            Date         Gold     Silver  Crude Oil       S&P500  \
# 2756 2020-07-27  1931.000000  24.476000  41.599998  3239.409912
# 2757 2020-07-28  1944.699951  24.266001  41.040001  3218.439941
# 2758 2020-07-29  1953.500000  24.292999  41.270000  3258.439941
# 2759 2020-07-30  1942.300049  23.340000  39.919998  3246.219971
# 2760 2020-07-31  1962.800049  24.188999  40.270000  3271.120117
#
#       Russel 2000 Index  10 Yr US T-Note futures  2 Yr US T-Note Futures  \
# 2756        1484.650024               139.468994              110.405998
# 2757        1469.760010               139.703003              110.430000
# 2758        1500.630005               139.750000              110.453003
# 2759        1495.099976               140.016006              110.464996
# 2760        1480.430054               140.078003              110.491997
#
#         Platinum  Copper  Dollar Index  Volatility Index  Soybean  \
# 2756  958.599976  2.8880     93.614998         24.740000   898.50
# 2757  977.900024  2.9050     93.647003         25.440001   888.25
# 2758  950.599976  2.9055     93.431999         24.100000   885.50
# 2759  905.900024  2.9045     93.009003         24.760000   887.25
# 2760  912.200012  2.8590     93.320999         24.459999   890.00
#
#       MSCI EM ETF  Euro USD  Euronext100        Nasdaq
# 2756    43.810001  1.176928   983.700012  10536.269531
# 2757    43.450001  1.171880   984.900024  10402.089844
# 2758    44.150002  1.178287   987.090027  10542.940430
# 2759    43.590000  1.187225   966.080017  10587.809570
# 2760    43.290001       NaN   954.260010  10745.269531

# %%
#Front filling the NaN values in the data set
values = values.fillna(method="ffill",axis=0)
values = values.fillna(method="bfill",axis=0)
values.isna().sum()
# Out:
# Date                       0
# Gold                       0
# Silver                     0
# Crude Oil                  0
# S&P500                     0
# Russel 2000 Index          0
# 10 Yr US T-Note futures    0
# 2 Yr US T-Note Futures     0
# Platinum                   0
# Copper                     0
# Dollar Index               0
# Volatility Index           0
# Soybean                    0
# MSCI EM ETF                0
# Euro USD                   0
# Euronext100                0
# Nasdaq                     0
# dtype: int64

# %%
# Co-ercing numeric type to all columns except Date
cols=values.columns.drop('Date')
values[cols] = values[cols].apply(pd.to_numeric,errors='coerce').round(decimals=1)
values.tail()
# Out:
#            Date    Gold  Silver  Crude Oil  S&P500  Russel 2000 Index  \
# 2756 2020-07-27  1931.0    24.5       41.6  3239.4             1484.7
# 2757 2020-07-28  1944.7    24.3       41.0  3218.4             1469.8
# 2758 2020-07-29  1953.5    24.3       41.3  3258.4             1500.6
# 2759 2020-07-30  1942.3    23.3       39.9  3246.2             1495.1
# 2760 2020-07-31  1962.8    24.2       40.3  3271.1             1480.4
#
#       10 Yr US T-Note futures  2 Yr US T-Note Futures  Platinum  Copper  \
# 2756                    139.5                   110.4     958.6     2.9
# 2757                    139.7                   110.4     977.9     2.9
# 2758                    139.8                   110.5     950.6     2.9
# 2759                    140.0                   110.5     905.9     2.9
# 2760                    140.1                   110.5     912.2     2.9
#
#       Dollar Index  Volatility Index  Soybean  MSCI EM ETF  Euro USD  \
# 2756          93.6              24.7    898.5         43.8       1.2
# 2757          93.6              25.4    888.2         43.5       1.2
# 2758          93.4              24.1    885.5         44.2       1.2
# 2759          93.0              24.8    887.2         43.6       1.2
# 2760          93.3              24.5    890.0         43.3       1.2
#
#       Euronext100   Nasdaq
# 2756        983.7  10536.3
# 2757        984.9  10402.1
# 2758        987.1  10542.9
# 2759        966.1  10587.8
# 2760        954.3  10745.3

# %%
values.to_csv("Training Data_Values.csv")

# %% [markdown]
# In approach we highlighted that we will used lagged returns of the listed instruments to predict future returns on Gold. Here we go on to calculate shortterm returns of all the instruments and longer term returns of few selected instruments. The fundamental idea behind it is, that if a certain asset has highly outperformed or underperformed, there is greater likelihood of portfolio rebalancing which would impact returns on other asset clasees. Eg: If the stock markets (S&P500) has shown stupendous returns in past 6 months, asset managers might want to book profits and allocate some funds to say precious metals and prepare for stock market correction. We will however, use Machine Learning to evaluate the hypothesis.

# %%
imp = ['Gold','Silver', 'Crude Oil', 'S&P500','MSCI EM ETF']
# Calculating Short term -Historical Returns
change_days = [1,3,5,14,21]

data = pd.DataFrame(data=values['Date'])
for i in change_days:
    print(data.shape)
    x= values[cols].pct_change(periods=i).add_suffix("-T-"+str(i))
    data=pd.concat(objs=(data,x),axis=1)
    x=[]
print(data.shape)

# Calculating Long term Historical Returns
change_days = [60,90,180,250]

for i in change_days:
    print(data.shape)
    x= values[imp].pct_change(periods=i).add_suffix("-T-"+str(i))
    data=pd.concat(objs=(data,x),axis=1)
    x=[]
print(data.shape)
# Out:
# (2761, 1)
# (2761, 17)
# (2761, 33)
# (2761, 49)
# (2761, 65)
# (2761, 81)
# (2761, 81)
# (2761, 86)
# (2761, 91)
# (2761, 96)
# (2761, 101)

# %% [markdown]
# Besides just the lagged returns, we also see how far the current Gold price is from its moving average for with different window. This is a very commonly used metric in technical analysis where moving averages offer supports and resistances for asset prices. We use a combination of simple and exponential moving averages. We then add these moving averages to the existing feature space.

# %%
#Calculating Moving averages for Gold
moving_avg = pd.DataFrame(values['Date'],columns=['Date'])
moving_avg['Date']=pd.to_datetime(moving_avg['Date'],format='%Y-%b-%d')
moving_avg['Gold/15SMA'] = (values['Gold']/(values['Gold'].rolling(window=15).mean()))-1
moving_avg['Gold/30SMA'] = (values['Gold']/(values['Gold'].rolling(window=30).mean()))-1
moving_avg['Gold/60SMA'] = (values['Gold']/(values['Gold'].rolling(window=60).mean()))-1
moving_avg['Gold/90SMA'] = (values['Gold']/(values['Gold'].rolling(window=90).mean()))-1
moving_avg['Gold/180SMA'] = (values['Gold']/(values['Gold'].rolling(window=180).mean()))-1
moving_avg['Gold/90EMA'] = (values['Gold']/(values['Gold'].ewm(span=90,adjust=True,ignore_na=True).mean()))-1
moving_avg['Gold/180EMA'] = (values['Gold']/(values['Gold'].ewm(span=180,adjust=True,ignore_na=True).mean()))-1
moving_avg = moving_avg.dropna(axis=0)
print(moving_avg.shape)
moving_avg.head()
# Out:
# (2582, 8)
#           Date  Gold/15SMA  Gold/30SMA  Gold/60SMA  Gold/90SMA  Gold/180SMA  \
# 179 2010-09-09    0.005005    0.020246    0.026862    0.026428     0.067496
# 180 2010-09-10    0.000536    0.014916    0.023422    0.022489     0.063095
# 181 2010-09-13    0.000043    0.013705    0.023840    0.022565     0.062965
# 182 2010-09-14    0.017736    0.031368    0.043642    0.042295     0.083187
# 183 2010-09-15    0.013857    0.026901    0.040711    0.039604     0.079958
#
#      Gold/90EMA  Gold/180EMA
# 179    0.032506     0.046162
# 180    0.028204     0.041912
# 181    0.028040     0.041852
# 182    0.047219     0.061593
# 183    0.043701     0.058291

# %%
#Merging Moving Average values to the feature space
print(data.shape)
data['Date']=pd.to_datetime(data['Date'],format='%Y-%b-%d')
data = pd.merge(left=data,right=moving_avg,how='left',on='Date')
print(data.shape)
data.isna().sum()
# Out:
# (2761, 101)
# (2761, 108)
# Date               0
# Gold-T-1           1
# Silver-T-1         1
# Crude Oil-T-1      1
# S&P500-T-1         1
#                 ...
# Gold/60SMA       179
# Gold/90SMA       179
# Gold/180SMA      179
# Gold/90EMA       179
# Gold/180EMA      179
# Length: 108, dtype: int64

# %% [markdown]
# This wall all about features. Now we need to create targets, i.e what we want to predict. Since we are predicting returns, we need to pick a horizon for which we need to predict returns. I have chosen 14-day and 22-day horizons because other smaller horizons tend to be very volatile and lack and predictive power. One can however, experiment with other horizons as well.

# %%
#Caluculating forward returns for Target
y = pd.DataFrame(data=values['Date'])
print(y.shape)

y['Gold-T+14']=values["Gold"].pct_change(periods=-14)
y['Gold-T+22']=values["Gold"].pct_change(periods=-22)
print(y.shape)
y.isna().sum()
# Out:
# (2761, 1)
# (2761, 3)
# Date          0
# Gold-T+14    14
# Gold-T+22    22
# dtype: int64

# %%
# Removing NAs
print(data.shape)
data = data[data['Gold-T-250'].notna()]
y = y[y['Gold-T+22'].notna()]
print(data.shape)
print(y.shape)
# Out:
# (2761, 108)
# (2511, 108)
# (2739, 3)

# %% [markdown]
# Now we will merge the Target variables with the feature space to get a data whcih we can finally start modelling on.

# %%
#Adding Target Variables
data = pd.merge(left=data,right=y,how='inner',on='Date',suffixes=(False,False))
print(data.shape)
data.isna().sum()
# Out:
# (2489, 110)
# Date             0
# Gold-T-1         0
# Silver-T-1       0
# Crude Oil-T-1    0
# S&P500-T-1       0
#                 ..
# Gold/180SMA      0
# Gold/90EMA       0
# Gold/180EMA      0
# Gold-T+14        0
# Gold-T+22        0
# Length: 110, dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(data['Gold-T+22'])
# Out:
# <AxesSubplot:xlabel='Gold-T+22'>

# %%
sns.distplot(data['Gold-T+14'])
# Out:
# <AxesSubplot:xlabel='Gold-T+14'>

# %%
data.to_csv("Training Data.csv",index=False)

# %% [markdown]
# ##Creating Labels
#
# We will try to predict any adverse (negative) return in Gold beyond a threshold.This threshold can be defined based on the risk tolerance of the investor. Here, I have taken the threshold to be 15% lowest return observations in the data history. In effect I am training to the model to predict a fall equal to or worse than 394 worse days in past 10 years.

# %%
import scipy.stats as st
#Select Threshold p (left tail probability)
p= 0.15
#Get z-Value
z = st.norm.ppf(p)
print(z)
# Out:
# -1.0364333894937898

# %%
#Calculating Threshold (t) for each Y
t_14 = round((z*np.std(data["Gold-T+14"]))+np.mean(data["Gold-T+14"]),5)
t_22 = round((z*np.std(data["Gold-T+22"]))+np.mean(data["Gold-T+22"]),5)

print("t_14=",t_14)
print("t_22=",t_22)
# Out:
# t_14= -0.03854
# t_22= -0.04788

# %% [markdown]
# So We can see above that threshold for 14-day model is -0.037 or -3.7%. This means that Gold returns over 140day period has been lower than -3.7% only 15 out of 100 days. We will label them as Target outcomes. Similar for T+22 days and T+5 Days

# %%
#Creating Labels
data['Y-14'] = (data['Gold-T+14']< t_14)*1
data['Y-22']= (data['Gold-T+22']< t_22)*1
print("Y-14", sum(data['Y-14']))
print("Y-22", sum(data['Y-22']))
# Out:
# Y-14 346
# Y-22 374

# %%
data.head()
# Out:
#         Date  Gold-T-1  Silver-T-1  Crude Oil-T-1  S&P500-T-1  \
# 0 2010-12-17  0.005984    0.010417       0.003421    0.000805
# 1 2010-12-20  0.005005    0.006873       0.009091    0.002573
# 2 2010-12-21  0.001949    0.003413       0.011261    0.006014
# 3 2010-12-22 -0.001009    0.000000       0.007795    0.003348
# 4 2010-12-23 -0.004903   -0.003401       0.011050   -0.001589
#
#    Russel 2000 Index-T-1  10 Yr US T-Note futures-T-1  \
# 0               0.003734                     0.008306
# 1               0.003592                    -0.000824
# 2               0.010482                    -0.000824
# 3               0.000127                    -0.009901
# 4              -0.002024                    -0.003333
#
#    2 Yr US T-Note Futures-T-1  Platinum-T-1  Copper-T-1  ...  Gold/30SMA  \
# 0                    0.000913      0.001415     0.02439  ...   -0.001805
# 1                    0.000000      0.007183     0.00000  ...    0.003610
# 2                   -0.000912      0.006547     0.02381  ...    0.006090
# 3                    0.000000      0.005227     0.00000  ...    0.005374
# 4                    0.000000     -0.004506     0.00000  ...    0.001003
#
#    Gold/60SMA  Gold/90SMA  Gold/180SMA  Gold/90EMA  Gold/180EMA  Gold-T+14  \
# 0    0.012638    0.040506     0.092005    0.035494     0.070472   0.005250
# 1    0.016601    0.044304     0.096390    0.039744     0.074871   0.012422
# 2    0.017567    0.044925     0.097391    0.040811     0.075992   0.010555
# 3    0.015569    0.042501     0.095189    0.038850     0.073962   0.002023
# 4    0.009699    0.036124     0.088766    0.032987     0.067834  -0.004113
#
#    Gold-T+22  Y-14  Y-22
# 0   0.007675     0     0
# 1   0.011166     0     0
# 2   0.030969     0     0
# 3   0.034154     0     0
# 4   0.026404     0     0
#
# [5 rows x 112 columns]

# %% [markdown]
# Now that we have the labels to predict, we can delet the return columns

# %%
data = data.drop(['Gold-T+14','Gold-T+22'],axis=1)
data.head()
# Out:
#         Date  Gold-T-1  Silver-T-1  Crude Oil-T-1  S&P500-T-1  \
# 0 2010-12-17  0.005984    0.010417       0.003421    0.000805
# 1 2010-12-20  0.005005    0.006873       0.009091    0.002573
# 2 2010-12-21  0.001949    0.003413       0.011261    0.006014
# 3 2010-12-22 -0.001009    0.000000       0.007795    0.003348
# 4 2010-12-23 -0.004903   -0.003401       0.011050   -0.001589
#
#    Russel 2000 Index-T-1  10 Yr US T-Note futures-T-1  \
# 0               0.003734                     0.008306
# 1               0.003592                    -0.000824
# 2               0.010482                    -0.000824
# 3               0.000127                    -0.009901
# 4              -0.002024                    -0.003333
#
#    2 Yr US T-Note Futures-T-1  Platinum-T-1  Copper-T-1  ...  \
# 0                    0.000913      0.001415     0.02439  ...
# 1                    0.000000      0.007183     0.00000  ...
# 2                   -0.000912      0.006547     0.02381  ...
# 3                    0.000000      0.005227     0.00000  ...
# 4                    0.000000     -0.004506     0.00000  ...
#
#    MSCI EM ETF-T-250  Gold/15SMA  Gold/30SMA  Gold/60SMA  Gold/90SMA  \
# 0           0.092754   -0.008206   -0.001805    0.012638    0.040506
# 1           0.086957   -0.004174    0.003610    0.016601    0.044304
# 2           0.097983   -0.002386    0.006090    0.017567    0.044925
# 3           0.097701   -0.003368    0.005374    0.015569    0.042501
# 4           0.104046   -0.007851    0.001003    0.009699    0.036124
#
#    Gold/180SMA  Gold/90EMA  Gold/180EMA  Y-14  Y-22
# 0     0.092005    0.035494     0.070472     0     0
# 1     0.096390    0.039744     0.074871     0     0
# 2     0.097391    0.040811     0.075992     0     0
# 3     0.095189    0.038850     0.073962     0     0
# 4     0.088766    0.032987     0.067834     0     0
#
# [5 rows x 110 columns]

# %% [markdown]
# ## 22-Day Model

# %%
from pycaret.classification import *

# %%
data_22 = data.drop(['Y-14'],axis=1)
s22 = setup(data=data_22, target='Y-22', session_id=11, silent=True);
data_22.head()
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_d21bd118_e36d_11ea_b819_c85b76978244" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row0_col1" class="data row0 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row3_col1" class="data row3 col1" >(2489, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row5_col1" class="data row5 col1" >107</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row10_col1" class="data row10 col1" >(2489, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row11_col1" class="data row11 col1" >(1742, 126)</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row12_col1" class="data row12 col1" >(747, 126)</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d21bd118_e36d_11ea_b819_c85b76978244level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_d21bd118_e36d_11ea_b819_c85b76978244row18_col1" class="data row18 col1" >None</td>
#             </tr>
#         Date  Gold-T-1  Silver-T-1  Crude Oil-T-1  S&P500-T-1  \
# 0 2010-12-17  0.005984    0.010417       0.003421    0.000805
# 1 2010-12-20  0.005005    0.006873       0.009091    0.002573
# 2 2010-12-21  0.001949    0.003413       0.011261    0.006014
# 3 2010-12-22 -0.001009    0.000000       0.007795    0.003348
# 4 2010-12-23 -0.004903   -0.003401       0.011050   -0.001589
#
#    Russel 2000 Index-T-1  10 Yr US T-Note futures-T-1  \
# 0               0.003734                     0.008306
# 1               0.003592                    -0.000824
# 2               0.010482                    -0.000824
# 3               0.000127                    -0.009901
# 4              -0.002024                    -0.003333
#
#    2 Yr US T-Note Futures-T-1  Platinum-T-1  Copper-T-1  ...  S&P500-T-250  \
# 0                    0.000913      0.001415     0.02439  ...      0.097882
# 1                    0.000000      0.007183     0.00000  ...      0.100706
# 2                   -0.000912      0.006547     0.02381  ...      0.103916
# 3                    0.000000      0.005227     0.00000  ...      0.107027
# 4                    0.000000     -0.004506     0.00000  ...      0.100815
#
#    MSCI EM ETF-T-250  Gold/15SMA  Gold/30SMA  Gold/60SMA  Gold/90SMA  \
# 0           0.092754   -0.008206   -0.001805    0.012638    0.040506
# 1           0.086957   -0.004174    0.003610    0.016601    0.044304
# 2           0.097983   -0.002386    0.006090    0.017567    0.044925
# 3           0.097701   -0.003368    0.005374    0.015569    0.042501
# 4           0.104046   -0.007851    0.001003    0.009699    0.036124
#
#    Gold/180SMA  Gold/90EMA  Gold/180EMA  Y-22
# 0     0.092005    0.035494     0.070472     0
# 1     0.096390    0.039744     0.074871     0
# 2     0.097391    0.040811     0.075992     0
# 3     0.095189    0.038850     0.073962     0
# 4     0.088766    0.032987     0.067834     0
#
# [5 rows x 109 columns]

# %%
compare_models(turbo=False)
# Out:
# <style  type="text/css" >
#     #T_45114728_e36f_11ea_811e_c85b76978244 th {
#           text-align: left;
#     }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row2_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row10_col0 {
#             text-align:  left;
#         }    #T_45114728_e36f_11ea_811e_c85b76978244row10_col1 {
#             : ;

# %%
mlp = create_model('mlp')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9200  0.9417  0.6667  0.7826  0.7200  0.6737
# 1       0.9371  0.9434  0.6667  0.9000  0.7660  0.7306
# 2       0.9080  0.9444  0.7308  0.6786  0.7037  0.6494
# 3       0.9253  0.9220  0.6538  0.8095  0.7234  0.6808
# 4       0.9425  0.9688  0.7308  0.8636  0.7917  0.7586
# 5       0.9483  0.9571  0.8462  0.8148  0.8302  0.7997
# 6       0.9368  0.9558  0.6923  0.8571  0.7660  0.7299
# 7       0.9080  0.9397  0.6154  0.7273  0.6667  0.6138
# 8       0.9080  0.9363  0.6154  0.7273  0.6667  0.6138
# 9       0.9483  0.9797  0.7692  0.8696  0.8163  0.7864
# Mean    0.9282  0.9489  0.6987  0.8030  0.7451  0.7036
# SD      0.0157  0.0159  0.0684  0.0693  0.0552  0.0641

# %%
lgbm = create_model('lightgbm')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9429  0.9772  0.7037  0.9048  0.7917  0.7592
# 1       0.9371  0.9825  0.5926  1.0000  0.7442  0.7110
# 2       0.9138  0.9587  0.6154  0.7619  0.6809  0.6317
# 3       0.9253  0.8979  0.5385  0.9333  0.6829  0.6440
# 4       0.9483  0.9849  0.6923  0.9474  0.8000  0.7711
# 5       0.9540  0.9764  0.7692  0.9091  0.8333  0.8069
# 6       0.9425  0.9836  0.6154  1.0000  0.7619  0.7313
# 7       0.9310  0.9392  0.6538  0.8500  0.7391  0.7002
# 8       0.9310  0.9782  0.6923  0.8182  0.7500  0.7103
# 9       0.9023  0.9870  0.4231  0.8462  0.5641  0.5159
# Mean    0.9328  0.9666  0.6296  0.8971  0.7348  0.6982
# SD      0.0150  0.0268  0.0928  0.0739  0.0728  0.0793

# %%
et = create_model('et')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9314  0.9782  0.6667  0.8571  0.7500  0.7110
# 1       0.9371  0.9915  0.6296  0.9444  0.7556  0.7211
# 2       0.8966  0.9598  0.5000  0.7222  0.5909  0.5339
# 3       0.9253  0.8824  0.6538  0.8095  0.7234  0.6808
# 4       0.9828  0.9949  0.8846  1.0000  0.9388  0.9288
# 5       0.9425  0.9402  0.6923  0.9000  0.7826  0.7501
# 6       0.9310  0.9654  0.5385  1.0000  0.7000  0.6650
# 7       0.9195  0.9650  0.5769  0.8333  0.6818  0.6375
# 8       0.9253  0.9775  0.6154  0.8421  0.7111  0.6694
# 9       0.9195  0.9843  0.5000  0.9286  0.6500  0.6091
# Mean    0.9311  0.9639  0.6258  0.8837  0.7284  0.6907
# SD      0.0209  0.0312  0.1075  0.0834  0.0876  0.0984

# %%
catb = create_model('catboost')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9029  0.9717  0.4815  0.8125  0.6047  0.5534
# 1       0.9371  0.9807  0.6296  0.9444  0.7556  0.7211
# 2       0.9138  0.9545  0.5385  0.8235  0.6512  0.6044
# 3       0.9195  0.8958  0.5769  0.8333  0.6818  0.6375
# 4       0.9540  0.9932  0.6923  1.0000  0.8182  0.7929
# 5       0.9598  0.9766  0.8077  0.9130  0.8571  0.8338
# 6       0.9425  0.9774  0.6154  1.0000  0.7619  0.7313
# 7       0.9195  0.9550  0.6154  0.8000  0.6957  0.6502
# 8       0.9080  0.9727  0.5000  0.8125  0.6190  0.5701
# 9       0.9195  0.9828  0.5000  0.9286  0.6500  0.6091
# Mean    0.9277  0.9661  0.5957  0.8868  0.7095  0.6704
# SD      0.0185  0.0260  0.0955  0.0754  0.0810  0.0902

# %%
mlp_tune = tune_model('mlp', n_iter=50,optimize='Recall')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8971  0.9269  0.6667  0.6667  0.6667  0.6059
# 1       0.9257  0.9272  0.6667  0.8182  0.7347  0.6920
# 2       0.9023  0.9470  0.8846  0.6216  0.7302  0.6727
# 3       0.9368  0.9337  0.6154  0.9412  0.7442  0.7099
# 4       0.9368  0.9777  0.7308  0.8261  0.7755  0.7389
# 5       0.9195  0.9426  0.6538  0.7727  0.7083  0.6620
# 6       0.9138  0.9467  0.6538  0.7391  0.6939  0.6439
# 7       0.9023  0.9184  0.6154  0.6957  0.6531  0.5965
# 8       0.8908  0.9348  0.5385  0.6667  0.5957  0.5334
# 9       0.9080  0.9171  0.6538  0.7083  0.6800  0.6264
# Mean    0.9133  0.9372  0.6679  0.7456  0.6982  0.6482
# SD      0.0153  0.0168  0.0859  0.0908  0.0494  0.0573

# %%
lgbm_tuned = tune_model('lightgbm',n_iter=50,optimize='Recall')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8971  0.9164  0.6296  0.6800  0.6538  0.5935
# 1       0.9029  0.9397  0.5185  0.7778  0.6222  0.5690
# 2       0.8966  0.9083  0.5769  0.6818  0.6250  0.5655
# 3       0.9080  0.8620  0.5385  0.7778  0.6364  0.5857
# 4       0.9368  0.9548  0.6538  0.8947  0.7556  0.7203
# 5       0.8851  0.9192  0.5000  0.6500  0.5652  0.5003
# 6       0.8908  0.9249  0.5000  0.6842  0.5778  0.5168
# 7       0.8966  0.8098  0.5000  0.7222  0.5909  0.5339
# 8       0.9138  0.8963  0.5385  0.8235  0.6512  0.6044
# 9       0.9425  0.9405  0.6923  0.9000  0.7826  0.7501
# Mean    0.9070  0.9072  0.5648  0.7592  0.6461  0.5940
# SD      0.0181  0.0408  0.0668  0.0861  0.0679  0.0776

# %%
et_tuned = tune_model ('et', n_iter=150)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9429  0.9821  0.7037  0.9048  0.7917  0.7592
# 1       0.9429  0.9865  0.6667  0.9474  0.7826  0.7509
# 2       0.9138  0.9591  0.5769  0.7895  0.6667  0.6185
# 3       0.8966  0.8832  0.4615  0.7500  0.5714  0.5164
# 4       0.9655  0.9926  0.7692  1.0000  0.8696  0.8501
# 5       0.9425  0.9560  0.6923  0.9000  0.7826  0.7501
# 6       0.9253  0.9743  0.5000  1.0000  0.6667  0.6298
# 7       0.9195  0.9406  0.5385  0.8750  0.6667  0.6238
# 8       0.9310  0.9756  0.6538  0.8500  0.7391  0.7002
# 9       0.9253  0.9856  0.5385  0.9333  0.6829  0.6440
# Mean    0.9305  0.9635  0.6101  0.8950  0.7220  0.6843
# SD      0.0181  0.0309  0.0957  0.0781  0.0823  0.0910

# %%
catb_tuned = tune_model('catboost',n_iter=150,optimize='Recall')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9143  0.9337  0.6296  0.7727  0.6939  0.6446
# 1       0.9314  0.9565  0.6667  0.8571  0.7500  0.7110
# 2       0.9023  0.9410  0.5385  0.7368  0.6222  0.5677
# 3       0.9368  0.9166  0.6538  0.8947  0.7556  0.7203
# 4       0.9368  0.9790  0.6923  0.8571  0.7660  0.7299
# 5       0.9483  0.9732  0.7692  0.8696  0.8163  0.7864
# 6       0.9483  0.9774  0.6538  1.0000  0.7907  0.7627
# 7       0.9195  0.9524  0.5769  0.8333  0.6818  0.6375
# 8       0.9080  0.9480  0.5769  0.7500  0.6522  0.6002
# 9       0.9195  0.9641  0.5769  0.8333  0.6818  0.6375
# Mean    0.9265  0.9542  0.6335  0.8405  0.7210  0.6798
# SD      0.0154  0.0192  0.0652  0.0731  0.0603  0.0686

# %% [markdown]
# #### Ensembling Modles

# %%
mlp_bagged = ensemble_model(estimator=mlp, method='Bagging')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8971  0.9334  0.5556  0.7143  0.6250  0.5665
# 1       0.9200  0.9462  0.5926  0.8421  0.6957  0.6512
# 2       0.8908  0.9441  0.5385  0.6667  0.5957  0.5334
# 3       0.9195  0.9122  0.6154  0.8000  0.6957  0.6502
# 4       0.9310  0.9680  0.6538  0.8500  0.7391  0.7002
# 5       0.9195  0.9452  0.5769  0.8333  0.6818  0.6375
# 6       0.9195  0.9470  0.6538  0.7727  0.7083  0.6620
# 7       0.9023  0.9319  0.5385  0.7368  0.6222  0.5677
# 8       0.8851  0.9267  0.5000  0.6500  0.5652  0.5003
# 9       0.9310  0.9639  0.6154  0.8889  0.7273  0.6893
# Mean    0.9116  0.9419  0.5840  0.7755  0.6656  0.6158
# SD      0.0156  0.0159  0.0489  0.0772  0.0562  0.0651

# %%
et_boosting = ensemble_model(estimator=et, method='Boosting')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9200  0.9718  0.5926  0.8421  0.6957  0.6512
# 1       0.9257  0.9875  0.5556  0.9375  0.6977  0.6585
# 2       0.8966  0.9531  0.4615  0.7500  0.5714  0.5164
# 3       0.9023  0.8862  0.4615  0.8000  0.5854  0.5345
# 4       0.9713  0.9947  0.8077  1.0000  0.8936  0.8772
# 5       0.9425  0.9511  0.6923  0.9000  0.7826  0.7501
# 6       0.9138  0.9636  0.5000  0.8667  0.6341  0.5892
# 7       0.9253  0.9436  0.6154  0.8421  0.7111  0.6694
# 8       0.9138  0.9769  0.5385  0.8235  0.6512  0.6044
# 9       0.9310  0.9849  0.5385  1.0000  0.7000  0.6650
# Mean    0.9242  0.9613  0.5764  0.8762  0.6923  0.6516
# SD      0.0202  0.0297  0.1021  0.0787  0.0896  0.0996

# %%
catb_tuned_boosted = ensemble_model(estimator=catb_tuned, method= 'Bagging')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9029  0.9482  0.4815  0.8125  0.6047  0.5534
# 1       0.9143  0.9732  0.5185  0.8750  0.6512  0.6059
# 2       0.9080  0.9558  0.5000  0.8125  0.6190  0.5701
# 3       0.9138  0.9129  0.5769  0.7895  0.6667  0.6185
# 4       0.9195  0.9771  0.5385  0.8750  0.6667  0.6238
# 5       0.9310  0.9537  0.6154  0.8889  0.7273  0.6893
# 6       0.9368  0.9797  0.5769  1.0000  0.7317  0.6988
# 7       0.9080  0.9192  0.5000  0.8125  0.6190  0.5701
# 8       0.9023  0.9615  0.5000  0.7647  0.6047  0.5517
# 9       0.9138  0.9605  0.4615  0.9231  0.6154  0.5728
# Mean    0.9150  0.9542  0.5269  0.8554  0.6506  0.6054
# SD      0.0108  0.0214  0.0464  0.0674  0.0452  0.0504

# %%
lgbm_bagged = ensemble_model(lgbm, method='Bagging')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8914  0.9695  0.4074  0.7857  0.5366  0.4820
# 1       0.9086  0.9760  0.4074  1.0000  0.5789  0.5376
# 2       0.9080  0.9545  0.5000  0.8125  0.6190  0.5701
# 3       0.9080  0.8893  0.4231  0.9167  0.5789  0.5351
# 4       0.9253  0.9800  0.5000  1.0000  0.6667  0.6298
# 5       0.9310  0.9725  0.6154  0.8889  0.7273  0.6893
# 6       0.9138  0.9821  0.4231  1.0000  0.5946  0.5551
# 7       0.9080  0.9267  0.5000  0.8125  0.6190  0.5701
# 8       0.9195  0.9696  0.5769  0.8333  0.6818  0.6375
# 9       0.9080  0.9896  0.4231  0.9167  0.5789  0.5351
# Mean    0.9122  0.9610  0.4776  0.8966  0.6182  0.5742
# SD      0.0105  0.0291  0.0701  0.0796  0.0549  0.0580

# %%
lgbm_boosted = ensemble_model(lgbm, method='Boosting')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9429  0.9752  0.7037  0.9048  0.7917  0.7592
# 1       0.9257  0.9795  0.5556  0.9375  0.6977  0.6585
# 2       0.9253  0.9553  0.6538  0.8095  0.7234  0.6808
# 3       0.9138  0.9103  0.5769  0.7895  0.6667  0.6185
# 4       0.9483  0.9743  0.7308  0.9048  0.8085  0.7790
# 5       0.9598  0.9732  0.8077  0.9130  0.8571  0.8338
# 6       0.9310  0.9841  0.5385  1.0000  0.7000  0.6650
# 7       0.9138  0.9371  0.5769  0.7895  0.6667  0.6185
# 8       0.9253  0.9696  0.6538  0.8095  0.7234  0.6808
# 9       0.9138  0.9865  0.4615  0.9231  0.6154  0.5728
# Mean    0.9300  0.9645  0.6259  0.8781  0.7251  0.6867
# SD      0.0150  0.0227  0.0980  0.0694  0.0701  0.0768

# %%
blend1 = blend_models(estimator_list=[mlp,lgbm,et])
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.9486  0.0  0.7037  0.9500  0.8085  0.7796
# 1       0.9486  0.0  0.6667  1.0000  0.8000  0.7718
# 2       0.9138  0.0  0.6154  0.7619  0.6809  0.6317
# 3       0.9310  0.0  0.6154  0.8889  0.7273  0.6893
# 4       0.9713  0.0  0.8462  0.9565  0.8980  0.8813
# 5       0.9655  0.0  0.8462  0.9167  0.8800  0.8599
# 6       0.9425  0.0  0.6154  1.0000  0.7619  0.7313
# 7       0.9310  0.0  0.6154  0.8889  0.7273  0.6893
# 8       0.9310  0.0  0.6538  0.8500  0.7391  0.7002
# 9       0.9253  0.0  0.5385  0.9333  0.6829  0.6440
# Mean    0.9409  0.0  0.6717  0.9146  0.7706  0.7378
# SD      0.0171  0.0  0.0963  0.0684  0.0715  0.0804

# %%
blend2 = blend_models(estimator_list=[lgbm,et], method='soft')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9429  0.9805  0.7037  0.9048  0.7917  0.7592
# 1       0.9371  0.9910  0.5926  1.0000  0.7442  0.7110
# 2       0.9080  0.9615  0.5769  0.7500  0.6522  0.6002
# 3       0.9253  0.8914  0.5385  0.9333  0.6829  0.6440
# 4       0.9598  0.9932  0.7308  1.0000  0.8444  0.8220
# 5       0.9483  0.9470  0.7308  0.9048  0.8085  0.7790
# 6       0.9425  0.9717  0.6154  1.0000  0.7619  0.7313
# 7       0.9310  0.9615  0.6538  0.8500  0.7391  0.7002
# 8       0.9368  0.9802  0.6923  0.8571  0.7660  0.7299
# 9       0.9138  0.9860  0.4615  0.9231  0.6154  0.5728
# Mean    0.9346  0.9664  0.6296  0.9123  0.7406  0.7050
# SD      0.0148  0.0286  0.0845  0.0755  0.0678  0.0746

# %% [markdown]
# ### Stacking Models

# %%
stack1 = create_stacknet(estimator_list=[[catb_tuned,blend2],[mlp]], restack=False)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9257  0.9752  0.7037  0.7917  0.7451  0.7018
# 1       0.9486  0.9885  0.7037  0.9500  0.8085  0.7796
# 2       0.9195  0.9621  0.6538  0.7727  0.7083  0.6620
# 3       0.9195  0.8963  0.6538  0.7727  0.7083  0.6620
# 4       0.9770  0.9927  0.9231  0.9231  0.9231  0.9096
# 5       0.9713  0.9535  0.8846  0.9200  0.9020  0.8851
# 6       0.9540  0.9758  0.6923  1.0000  0.8182  0.7929
# 7       0.9195  0.9657  0.6538  0.7727  0.7083  0.6620
# 8       0.9368  0.9784  0.7692  0.8000  0.7843  0.7473
# 9       0.9425  0.9849  0.6923  0.9000  0.7826  0.7501
# Mean    0.9415  0.9673  0.7330  0.8603  0.7889  0.7552
# SD      0.0202  0.0263  0.0918  0.0825  0.0731  0.0847

# %%
stacknet2 = stack_models(estimator_list=[catb_tuned,blend2], meta_model=mlp, restack=True)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9257  0.9309  0.7778  0.7500  0.7636  0.7196
# 1       0.9371  0.9294  0.7037  0.8636  0.7755  0.7394
# 2       0.9080  0.9236  0.6923  0.6923  0.6923  0.6383
# 3       0.9138  0.8919  0.6538  0.7391  0.6939  0.6439
# 4       0.9713  0.9693  0.8462  0.9565  0.8980  0.8813
# 5       0.9425  0.9345  0.8462  0.7857  0.8148  0.7809
# 6       0.9195  0.9602  0.6538  0.7727  0.7083  0.6620
# 7       0.9138  0.9345  0.6154  0.7619  0.6809  0.6317
# 8       0.9080  0.9374  0.6538  0.7083  0.6800  0.6264
# 9       0.9253  0.9810  0.6538  0.8095  0.7234  0.6808
# Mean    0.9265  0.9393  0.7097  0.7840  0.7431  0.7004
# SD      0.0185  0.0241  0.0797  0.0739  0.0671  0.0776

# %%
stack3 = stack_models(estimator_list=[catb_tuned,blend2], meta_model=mlp, restack=False)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9371  0.9752  0.7778  0.8077  0.7925  0.7554
# 1       0.9429  0.9885  0.7037  0.9048  0.7917  0.7592
# 2       0.9253  0.9621  0.6923  0.7826  0.7347  0.6914
# 3       0.9195  0.8963  0.6923  0.7500  0.7200  0.6731
# 4       0.9770  0.9927  0.9231  0.9231  0.9231  0.9096
# 5       0.9655  0.9535  0.8846  0.8846  0.8846  0.8643
# 6       0.9540  0.9758  0.6923  1.0000  0.8182  0.7929
# 7       0.9138  0.9657  0.6538  0.7391  0.6939  0.6439
# 8       0.9368  0.9784  0.7692  0.8000  0.7843  0.7473
# 9       0.9483  0.9849  0.7308  0.9048  0.8085  0.7790
# Mean    0.9420  0.9673  0.7520  0.8497  0.7951  0.7616
# SD      0.0190  0.0263  0.0842  0.0813  0.0669  0.0778

# %%
stack4 = create_stacknet(estimator_list=[[catb_tuned,blend2,mlp],[mlp]], restack=False)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9314  0.9737  0.7407  0.8000  0.7692  0.7290
# 1       0.9486  0.9875  0.7037  0.9500  0.8085  0.7796
# 2       0.9253  0.9636  0.6923  0.7826  0.7347  0.6914
# 3       0.9253  0.9077  0.6923  0.7826  0.7347  0.6914
# 4       0.9713  0.9917  0.9231  0.8889  0.9057  0.8887
# 5       0.9655  0.9522  0.8846  0.8846  0.8846  0.8643
# 6       0.9483  0.9922  0.6538  1.0000  0.7907  0.7627
# 7       0.9195  0.9665  0.6538  0.7727  0.7083  0.6620
# 8       0.9310  0.9753  0.7308  0.7917  0.7600  0.7198
# 9       0.9425  0.9854  0.6923  0.9000  0.7826  0.7501
# Mean    0.9409  0.9696  0.7368  0.8553  0.7879  0.7539
# SD      0.0167  0.0241  0.0880  0.0764  0.0607  0.0701

# %%
evaluate_model(mlp)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(et)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(lgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
a =predict_model(stack3)
# Out:
#                  Model  Accuracy     AUC  Recall   Prec.   F1   Kappa
# 0  Stacking Classifier    0.9438  0.9625    0.75  0.8571  0.8  0.7675

# %%
a['Label'].sum()
# Out:
# 98

# %%
a['Y-22'].sum()
# Out:
# 112

# %%
a.shape
# Out:
# (747, 129)

# %%
classifier_22 = finalize_model(stack3)

# %%
save_model(classifier_22,"22D Classifier")
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ## 14- Day Model

# %%
data_14 = data.drop(['Y-22'],axis=1)

# %%
s14 = setup(data=data_14, target='Y-14', session_id=11, silent=True, ignore_features=['Date']);
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_d018a446_e380_11ea_8ffa_c85b76978244" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row0_col1" class="data row0 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row3_col1" class="data row3 col1" >(2489, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row5_col1" class="data row5 col1" >107</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row10_col1" class="data row10 col1" >(2489, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row11_col1" class="data row11 col1" >(1742, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row12_col1" class="data row12 col1" >(747, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d018a446_e380_11ea_8ffa_c85b76978244level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_d018a446_e380_11ea_8ffa_c85b76978244row18_col1" class="data row18 col1" >None</td>
#             </tr>

# %%
compare_models(sort='Recall', turbo= False)
# Out:
# <style  type="text/css" >
#     #T_186aeab0_e382_11ea_bde9_c85b76978244 th {
#           text-align: left;
#     }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col4 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row10_col0 {
#             text-align:  left;
#         }    #T_186aeab0_e382_11ea_bde9_c85b76978244row10_col1 {
#             : ;

# %%
mlp14 = create_model('mlp')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9314  0.9269  0.8000  0.7407  0.7692  0.7290
# 1       0.9143  0.9192  0.5600  0.7778  0.6512  0.6038
# 2       0.9368  0.9444  0.7083  0.8095  0.7556  0.7194
# 3       0.9195  0.9617  0.7500  0.6923  0.7200  0.6731
# 4       0.8793  0.9008  0.2917  0.6364  0.4000  0.3430
# 5       0.9425  0.9256  0.6667  0.8889  0.7619  0.7300
# 6       0.9253  0.9125  0.7083  0.7391  0.7234  0.6802
# 7       0.9253  0.9067  0.6667  0.7619  0.7111  0.6684
# 8       0.9080  0.9353  0.6667  0.6667  0.6667  0.6133
# 9       0.9253  0.9275  0.7083  0.7391  0.7234  0.6802
# Mean    0.9208  0.9261  0.6527  0.7452  0.6882  0.6441
# SD      0.0168  0.0171  0.1342  0.0686  0.1027  0.1084

# %%
knn14_tuned = tune_model('knn', n_iter=100)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9029  0.9061  0.8000  0.6250  0.7018  0.6448
# 1       0.9143  0.8980  0.7200  0.6923  0.7059  0.6557
# 2       0.9368  0.9397  0.7500  0.7826  0.7660  0.7294
# 3       0.9253  0.9508  0.8750  0.6774  0.7636  0.7201
# 4       0.9253  0.8833  0.5833  0.8235  0.6829  0.6420
# 5       0.9080  0.8915  0.7083  0.6538  0.6800  0.6264
# 6       0.9425  0.9151  0.7917  0.7917  0.7917  0.7583
# 7       0.9310  0.8633  0.7500  0.7500  0.7500  0.7100
# 8       0.9368  0.9353  0.7917  0.7600  0.7755  0.7387
# 9       0.9598  0.9510  0.8750  0.8400  0.8571  0.8337
# Mean    0.9283  0.9134  0.7645  0.7396  0.7474  0.7059
# SD      0.0162  0.0286  0.0810  0.0699  0.0528  0.0613

# %%
dt14 = create_model('dt')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8514  0.7133  0.5200  0.4815  0.5000  0.4129
# 1       0.8857  0.7667  0.6000  0.6000  0.6000  0.5333
# 2       0.8736  0.7342  0.5417  0.5417  0.5417  0.4683
# 3       0.8333  0.6583  0.4167  0.4000  0.4082  0.3112
# 4       0.8851  0.6883  0.4167  0.6250  0.5000  0.4380
# 5       0.8966  0.8175  0.7083  0.6071  0.6538  0.5935
# 6       0.8333  0.6758  0.4583  0.4074  0.4314  0.3341
# 7       0.8333  0.6233  0.3333  0.3810  0.3556  0.2603
# 8       0.8851  0.7583  0.5833  0.5833  0.5833  0.5167
# 9       0.8908  0.7267  0.5000  0.6316  0.5581  0.4968
# Mean    0.8668  0.7163  0.5078  0.5259  0.5132  0.4365
# SD      0.0248  0.0542  0.1026  0.0946  0.0883  0.1014

# %%
dt_boosted = ensemble_model(dt14, method='Boosting')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.8343  0.6533  0.4000  0.4167  0.4082  0.3119
# 1       0.8800  0.7467  0.5600  0.5833  0.5714  0.5017
# 2       0.8736  0.6992  0.4583  0.5500  0.5000  0.4283
# 3       0.8563  0.7242  0.5417  0.4815  0.5098  0.4260
# 4       0.8851  0.7233  0.5000  0.6000  0.5455  0.4803
# 5       0.8621  0.7275  0.5417  0.5000  0.5200  0.4396
# 6       0.8333  0.7108  0.5417  0.4194  0.4727  0.3756
# 7       0.8276  0.6200  0.3333  0.3636  0.3478  0.2487
# 8       0.9195  0.8308  0.7083  0.7083  0.7083  0.6617
# 9       0.9023  0.7333  0.5000  0.7059  0.5854  0.5318
# Mean    0.8674  0.7169  0.5085  0.5329  0.5169  0.4406
# SD      0.0290  0.0530  0.0954  0.1126  0.0937  0.1098

# %%
blend14_1 = blend_models(estimator_list=[knn14_tuned,dt14,mlp14])
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.9314  0.0  0.8000  0.7407  0.7692  0.7290
# 1       0.9200  0.0  0.6800  0.7391  0.7083  0.6621
# 2       0.9368  0.0  0.7083  0.8095  0.7556  0.7194
# 3       0.9310  0.0  0.7917  0.7308  0.7600  0.7198
# 4       0.9195  0.0  0.4583  0.9167  0.6111  0.5717
# 5       0.9425  0.0  0.7500  0.8182  0.7826  0.7496
# 6       0.9310  0.0  0.7083  0.7727  0.7391  0.6995
# 7       0.9138  0.0  0.6667  0.6957  0.6809  0.6310
# 8       0.9425  0.0  0.7500  0.8182  0.7826  0.7496
# 9       0.9483  0.0  0.7083  0.8947  0.7907  0.7616
# Mean    0.9317  0.0  0.7022  0.7936  0.7380  0.6993
# SD      0.0107  0.0  0.0914  0.0682  0.0536  0.0574

# %%
stack14_1 = stack_models(estimator_list = [knn14_tuned, dt14, blend14_1], restack= False)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9314  0.9040  0.8000  0.7407  0.7692  0.7290
# 1       0.9257  0.9185  0.7200  0.7500  0.7347  0.6915
# 2       0.9368  0.9628  0.7083  0.8095  0.7556  0.7194
# 3       0.9310  0.9519  0.7083  0.7727  0.7391  0.6995
# 4       0.9253  0.8814  0.5000  0.9231  0.6486  0.6109
# 5       0.9425  0.9097  0.7083  0.8500  0.7727  0.7401
# 6       0.9425  0.9110  0.7500  0.8182  0.7826  0.7496
# 7       0.9310  0.8728  0.6667  0.8000  0.7273  0.6882
# 8       0.9425  0.9371  0.7083  0.8500  0.7727  0.7401
# 9       0.9598  0.9482  0.7500  0.9474  0.8372  0.8146
# Mean    0.9369  0.9197  0.7020  0.8262  0.7540  0.7183
# SD      0.0099  0.0285  0.0753  0.0650  0.0459  0.0498

# %%
stack14_2 = stack_models(estimator_list = [knn14_tuned, dt14, mlp14], meta_model= blend14_1,restack= True)
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.9314  0.0  0.8800  0.7097  0.7857  0.7455
# 1       0.9200  0.0  0.7200  0.7200  0.7200  0.6733
# 2       0.9483  0.0  0.7917  0.8261  0.8085  0.7786
# 3       0.9195  0.0  0.7500  0.6923  0.7200  0.6731
# 4       0.9080  0.0  0.4583  0.7857  0.5789  0.5313
# 5       0.8908  0.0  0.5833  0.6087  0.5957  0.5327
# 6       0.9425  0.0  0.7917  0.7917  0.7917  0.7583
# 7       0.9080  0.0  0.6250  0.6818  0.6522  0.5993
# 8       0.9368  0.0  0.8333  0.7407  0.7843  0.7474
# 9       0.9598  0.0  0.7917  0.9048  0.8444  0.8215
# Mean    0.9265  0.0  0.7225  0.7461  0.7282  0.6861
# SD      0.0200  0.0  0.1228  0.0795  0.0873  0.0973

# %%
stack14_3 = stack_models(estimator_list = [knn14_tuned, dt14, mlp14], meta_model= blend14_1,restack= False)
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.9029  0.0  0.7600  0.6333  0.6909  0.6338
# 1       0.8971  0.0  0.6400  0.6400  0.6400  0.5800
# 2       0.9310  0.0  0.7083  0.7727  0.7391  0.6995
# 3       0.8851  0.0  0.6667  0.5714  0.6154  0.5483
# 4       0.8908  0.0  0.3333  0.7273  0.4571  0.4056
# 5       0.9195  0.0  0.6667  0.7273  0.6957  0.6494
# 6       0.9195  0.0  0.7500  0.6923  0.7200  0.6731
# 7       0.9310  0.0  0.7083  0.7727  0.7391  0.6995
# 8       0.8908  0.0  0.6667  0.5926  0.6275  0.5637
# 9       0.9195  0.0  0.6250  0.7500  0.6818  0.6362
# Mean    0.9087  0.0  0.6525  0.6880  0.6607  0.6089
# SD      0.0165  0.0  0.1143  0.0702  0.0796  0.0845

# %%
classifier_14 = finalize_model(stack14_2)

# %%
save_model(classifier_14, "14D Classifier")
# Out:
# Transformation Pipeline and Model Succesfully Saved
