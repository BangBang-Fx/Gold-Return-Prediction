# %% [markdown]
# # Predicting return from Gold

# %% [markdown]
# ### Background

# %% [markdown]
# Gold has been the original store of value and medium of exchange for mankind for centuries till paper/or fiat currency took over a couple of centuries ago. However, most of the sustainable paper currencyies were backed by Gold as late as 1971, when the Bretton Woods agreement was scrapped and world currencies became a true $'Fiat'$ currency.
#
# Gold however continues to be os interest not only as metal of choice for jewellery, but also as store of value and often advisable part of investment portfolio as it tends to be a hedge and safe haven when economies tend to (or atleat appear to) be in or at brink of collapse.
#
# Currently there are numerous instruments which can give an investor exposure to Gold and they not necessarily need to keep it physically in their vaults. Exchange traded Funds (ETFs) is the most widely used instrument. As of April 2020, a total of **USD175bn** is invested in Gold ETFs across the globe. This was corpus was just **USD24bn in 2008** before the Global Financial Crisis (GFC)

# %% [markdown]
# ### Approach

# %% [markdown]
# In the series we will take different approaches to predict return from Gold prices using Machine learning. We will use supervised learning methods of regression and classification. We will then use Time Series methods. And then finally we will try to integrate them to see of their predictive ppowers increases due to integration.
#
# First we will go the regression route to predict future returns of Gold over next 2 weeks and 3 weeks period. We will do this by using historical returns of different instruments which I beleive impact or likely to impact the outlook towards Gold. The fundamental reason is, I term Gold as a 'reactionary' asset. It has little fundamentals of its own and movement in prices is often is a derivative of how investors view other asset classes (equities and commdities)

# %% [markdown]
# ## Importing and Preparing Data

# %% [markdown]
# For this and subsequent exercises we will need closing price of several instruments for past 10 years . There are various paid (Reuters, Bloomberg) and free resources (IEX, Quandl, Yahoofinance, Google finance) that we can use to either extract and load data in csv or we can directly call their APIs. Since in this project I needed different type of asset classes (Equities, Commodities, Debt and precious metals) I found the 'yahoofinancials' package to be very helpful and straight forward. (https://pypi.org/project/yahoofinancials/)

# %%
#Importing Libraries
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from yahoofinancials import YahooFinancials

# %% [markdown]
# I have prepared a list instruments for which we need to import data. yahoofinancials package requires Yahoo ticker symbols. The list contains the ticker symbols and their descriptions. The excel file containing the list can be found here..... We import that file and extract the tciker symbols and the names as seprarate lists

# %%
ticker_details = pd.read_excel(r"C:\Users\Arun Sabarish\Documents\GitHub\Gold-Return-Prediction\Ticker List.xlsx")
ticker_details.head(20)
# Out:
#       Ticker              Description
# 0       GC=F                     Gold
# 1       SI=F                   Silver
# 2       CL=F                Crude Oil
# 3      ^GSPC                   S&P500
# 4       ^RUT        Russel 2000 Index
# 5       ZN=F  10 Yr US T-Note futures
# 6       ZT=F   2 Yr US T-Note Futures
# 7       PL=F                 Platinum
# 8       HG=F                   Copper
# 9       DX=F             Dollar Index
# 10      ^VIX         Volatility Index
# 11       S=F                  Soybean
# 12       EEM              MSCI EM ETF
# 13  EURUSD=X                 Euro USD
# 14     ^N100              Euronext100
# 15     ^IXIC                   Nasdaq

# %%
ticker = ticker_details['Ticker'].to_list()
names = ticker_details['Description'].to_list()

# %% [markdown]
# Once we have the list, we need to define what date range we need to import the data for. The period I have chosen is Jan 2010 till 1st Mar 2020. The reason I did not pull data prior to that is because the GFC in 2008-09 massively changed the economic and market landscapes. Relationships pririo to that peirod might be of less relevance now. We also dont want to feed very less data as the models might tend to overfit.
#
# We create a date-range and write it to an empty dataframe named values where we would extract and past the values we pull from yahoofinancials.

# %%
#Extracting Data from Yahoo Finance and Adding them to Values table using date as key
end_date= "2020-07-28"
start_date = "2010-01-01"
date_range = pd.bdate_range(start=start_date,end=end_date)
values = pd.DataFrame({ 'Date': date_range})
values['Date']= pd.to_datetime(values['Date'])

# %% [markdown]
# Once we have the date range in dataframe, we need to use ticker symbols to pull out data from the API. yahoofinancials returns the output in a JSON format. The following code loops over the the list of ticker symbols and extracts just the closing prices for all the historical dates and keeps them adding to the dataframe horizontally. Note I have used the merge function to mantain the sanctity of dates. Given these asset classes might have different regional and trading holidays, the date ranges are not bound to be the same. By merging, we will eventually have several NAs which we will frontfill later on.

# %%
#Extracting Data from Yahoo Finance and Adding them to Values table using date as key
for i in ticker:
    raw_data = YahooFinancials(i)
    raw_data = raw_data.get_historical_price_data(start_date, end_date, "daily")
    df = pd.DataFrame(raw_data[i]['prices'])[['formatted_date','adjclose']]
    df.columns = ['Date1',i]
    df['Date1']= pd.to_datetime(df['Date1'])
    values = values.merge(df,how='left',left_on='Date',right_on='Date1')
    values = values.drop(labels='Date1',axis=1)

#Renaming columns to represent instrument names rather than their ticker codes for ease of readability
names.insert(0,'Date')
values.columns = names
print(values.shape)
print(values.isna().sum())
values.tail()
# Out:
# (2651, 17)
# Date                         0
# Gold                       117
# Silver                     117
# Crude Oil                  116
# S&P500                      95
# Russel 2000 Index           95
# 10 Yr US T-Note futures    118
# 2 Yr US T-Note Futures     116
# Platinum                   117
# Copper                     117
# Dollar Index               118
# Volatility Index            95
# Soybean                    116
# MSCI EM ETF                 95
# Euro USD                   311
# Euronext100                 55
# Nasdaq                      95
# dtype: int64
#            Date         Gold     Silver  Crude Oil       S&P500  \
# 2646 2020-02-24  1672.400024  18.868000  51.430000  3225.889893
# 2647 2020-02-25  1646.900024  18.183001  49.900002  3128.209961
# 2648 2020-02-26  1640.000000  17.826000  48.730000  3116.389893
# 2649 2020-02-27  1643.099976  17.799999  46.810001  2978.760010
# 2650 2020-02-28  1642.500000  17.658001  47.090000  2954.219971
#
#       Russel 2000 Index  10 Yr US T-Note futures  2 Yr US T-Note Futures  \
# 2646        1628.099976               132.656006              108.273003
# 2647        1571.900024               133.125000              108.398003
# 2648        1552.760010               133.328003              108.480003
# 2649        1497.869995               133.218994              108.698997
# 2650        1476.430054               133.328003              108.773003
#
#         Platinum  Copper  Dollar Index  Volatility Index  Soybean  \
# 2646  971.700012  2.5925     99.283997         25.030001   874.25
# 2647  929.799988  2.5965     98.901001         27.850000   879.00
# 2648  912.299988  2.5765     98.901001         27.559999   881.00
# 2649  904.299988  2.5690     98.938004         39.160000   895.00
# 2650  905.500000  2.5715     98.460999         40.110001   891.75
#
#       MSCI EM ETF  Euro USD  Euronext100       Nasdaq
# 2646    41.429615  1.083905  1120.449951  9221.280273
# 2647    41.101521  1.084920  1099.270020  8965.610352
# 2648    41.429615  1.088200  1099.410034  8980.780273
# 2649    40.435383  1.088589  1059.359985  8566.480469
# 2650    40.286251  1.099723  1021.979980  8567.370117

# %%
#Front filling the NaN values in the data set
values = values.fillna(method="ffill",axis=0)
values = values.fillna(method="bfill",axis=0)
values.isna().sum()
# Out:
# Date                       0
# Gold                       0
# Silver                     0
# Crude Oil                  0
# S&P500                     0
# Russel 2000 Index          0
# 10 Yr US T-Note futures    0
# 2 Yr US T-Note Futures     0
# Platinum                   0
# Copper                     0
# Dollar Index               0
# Volatility Index           0
# Soybean                    0
# MSCI EM ETF                0
# Euro USD                   0
# Euronext100                0
# Nasdaq                     0
# dtype: int64

# %%
# Co-ercing numeric type to all columns except Date
cols=values.columns.drop('Date')
values[cols] = values[cols].apply(pd.to_numeric,errors='coerce').round(decimals=1)
values.tail()
# Out:
#            Date    Gold  Silver  Crude Oil  S&P500  Russel 2000 Index  \
# 2646 2020-02-24  1672.4    18.9       51.4  3225.9             1628.1
# 2647 2020-02-25  1646.9    18.2       49.9  3128.2             1571.9
# 2648 2020-02-26  1640.0    17.8       48.7  3116.4             1552.8
# 2649 2020-02-27  1643.1    17.8       46.8  2978.8             1497.9
# 2650 2020-02-28  1642.5    17.7       47.1  2954.2             1476.4
#
#       10 Yr US T-Note futures  2 Yr US T-Note Futures  Platinum  Copper  \
# 2646                    132.7                   108.3     971.7     2.6
# 2647                    133.1                   108.4     929.8     2.6
# 2648                    133.3                   108.5     912.3     2.6
# 2649                    133.2                   108.7     904.3     2.6
# 2650                    133.3                   108.8     905.5     2.6
#
#       Dollar Index  Volatility Index  Soybean  MSCI EM ETF  Euro USD  \
# 2646          99.3              25.0    874.2         41.4       1.1
# 2647          98.9              27.9    879.0         41.1       1.1
# 2648          98.9              27.6    881.0         41.4       1.1
# 2649          98.9              39.2    895.0         40.4       1.1
# 2650          98.5              40.1    891.8         40.3       1.1
#
#       Euronext100  Nasdaq
# 2646       1120.4  9221.3
# 2647       1099.3  8965.6
# 2648       1099.4  8980.8
# 2649       1059.4  8566.5
# 2650       1022.0  8567.4

# %%
values.to_csv("Training Data_Values.csv")

# %% [markdown]
# In approach we highlighted that we will used lagged returns of the listed instruments to predict future returns on Gold. Here we go on to calculate shortterm returns of all the instruments and longer term returns of few selected instruments. The fundamental idea behind it is, that if a certain asset has highly outperformed or underperformed, there is greater likelihood of portfolio rebalancing which would impact returns on other asset clasees. Eg: If the stock markets (S&P500) has shown stupendous returns in past 6 months, asset managers might want to book profits and allocate some funds to say precious metals and prepare for stock market correction. We will however, use Machine Learning to evaluate the hypothesis.

# %%
imp = ['Gold','Silver', 'Crude Oil', 'S&P500','MSCI EM ETF']
# Calculating Short term -Historical Returns
change_days = [1,3,5,14,21]

data = pd.DataFrame(data=values['Date'])
for i in change_days:
    print(data.shape)
    x= values[cols].pct_change(periods=i).add_suffix("-T-"+str(i))
    data=pd.concat(objs=(data,x),axis=1)
    x=[]
print(data.shape)

# Calculating Long term Historical Returns
change_days = [60,90,180,250]

for i in change_days:
    print(data.shape)
    x= values[imp].pct_change(periods=i).add_suffix("-T-"+str(i))
    data=pd.concat(objs=(data,x),axis=1)
    x=[]
print(data.shape)
# Out:
# (2651, 1)
# (2651, 17)
# (2651, 33)
# (2651, 49)
# (2651, 65)
# (2651, 81)
# (2651, 81)
# (2651, 86)
# (2651, 91)
# (2651, 96)
# (2651, 101)

# %% [markdown]
# Besides just the lagged returns, we also see how far the current Gold price is from its moving average for with different window. This is a very commonly used metric in technical analysis where moving averages offer supports and resistances for asset prices. We use a combination of simple and exponential moving averages. We then add these moving averages to the existing feature space.

# %%
#Calculating Moving averages for Gold
moving_avg = pd.DataFrame(values['Date'],columns=['Date'])
moving_avg['Date']=pd.to_datetime(moving_avg['Date'],format='%Y-%b-%d')
moving_avg['Gold/15SMA'] = (values['Gold']/(values['Gold'].rolling(window=15).mean()))-1
moving_avg['Gold/30SMA'] = (values['Gold']/(values['Gold'].rolling(window=30).mean()))-1
moving_avg['Gold/60SMA'] = (values['Gold']/(values['Gold'].rolling(window=60).mean()))-1
moving_avg['Gold/90SMA'] = (values['Gold']/(values['Gold'].rolling(window=90).mean()))-1
moving_avg['Gold/180SMA'] = (values['Gold']/(values['Gold'].rolling(window=180).mean()))-1
moving_avg['Gold/90EMA'] = (values['Gold']/(values['Gold'].ewm(span=90,adjust=True,ignore_na=True).mean()))-1
moving_avg['Gold/180EMA'] = (values['Gold']/(values['Gold'].ewm(span=180,adjust=True,ignore_na=True).mean()))-1
moving_avg = moving_avg.dropna(axis=0)
print(moving_avg.shape)
moving_avg.head()
# Out:
# (2472, 8)
#           Date  Gold/15SMA  Gold/30SMA  Gold/60SMA  Gold/90SMA  Gold/180SMA  \
# 179 2010-09-09    0.005005    0.020246    0.026862    0.026428     0.067496
# 180 2010-09-10    0.000536    0.014916    0.023422    0.022489     0.063095
# 181 2010-09-13    0.000043    0.013705    0.023840    0.022565     0.062965
# 182 2010-09-14    0.017736    0.031368    0.043642    0.042295     0.083187
# 183 2010-09-15    0.013857    0.026901    0.040711    0.039604     0.079958
#
#      Gold/90EMA  Gold/180EMA
# 179    0.032506     0.046162
# 180    0.028204     0.041912
# 181    0.028040     0.041852
# 182    0.047219     0.061593
# 183    0.043701     0.058291

# %%
#Merging Moving Average values to the feature space
print(data.shape)
data['Date']=pd.to_datetime(data['Date'],format='%Y-%b-%d')
data = pd.merge(left=data,right=moving_avg,how='left',on='Date')
print(data.shape)
data.isna().sum()
# Out:
# (2651, 101)
# (2651, 108)
# Date                             0
# Gold-T-1                         1
# Silver-T-1                       1
# Crude Oil-T-1                    1
# S&P500-T-1                       1
# Russel 2000 Index-T-1            1
# 10 Yr US T-Note futures-T-1      1
# 2 Yr US T-Note Futures-T-1       1
# Platinum-T-1                     1
# Copper-T-1                       1
# Dollar Index-T-1                 1
# Volatility Index-T-1             1
# Soybean-T-1                      1
# MSCI EM ETF-T-1                  1
# Euro USD-T-1                     1
# Euronext100-T-1                  1
# Nasdaq-T-1                       1
# Gold-T-3                         3
# Silver-T-3                       3
# Crude Oil-T-3                    3
# S&P500-T-3                       3
# Russel 2000 Index-T-3            3
# 10 Yr US T-Note futures-T-3      3
# 2 Yr US T-Note Futures-T-3       3
# Platinum-T-3                     3
# Copper-T-3                       3
# Dollar Index-T-3                 3
# Volatility Index-T-3             3
# Soybean-T-3                      3
# MSCI EM ETF-T-3                  3
#                               ...
# Euro USD-T-21                   21
# Euronext100-T-21                21
# Nasdaq-T-21                     21
# Gold-T-60                       60
# Silver-T-60                     60
# Crude Oil-T-60                  60
# S&P500-T-60                     60
# MSCI EM ETF-T-60                60
# Gold-T-90                       90
# Silver-T-90                     90
# Crude Oil-T-90                  90
# S&P500-T-90                     90
# MSCI EM ETF-T-90                90
# Gold-T-180                     180
# Silver-T-180                   180
# Crude Oil-T-180                180
# S&P500-T-180                   180
# MSCI EM ETF-T-180              180
# Gold-T-250                     250
# Silver-T-250                   250
# Crude Oil-T-250                250
# S&P500-T-250                   250
# MSCI EM ETF-T-250              250
# Gold/15SMA                     179
# Gold/30SMA                     179
# Gold/60SMA                     179
# Gold/90SMA                     179
# Gold/180SMA                    179
# Gold/90EMA                     179
# Gold/180EMA                    179
# Length: 108, dtype: int64

# %% [markdown]
# This wall all about features. Now we need to create targets, i.e what we want to predict. Since we are predicting returns, we need to pick a horizon for which we need to predict returns. I have chosen 14-day and 22-day horizons because other smaller horizons tend to be very volatile and lack and predictive power. One can however, experiment with other horizons as well.

# %%
#Caluculating forward returns for Target
y = pd.DataFrame(data=values['Date'])
print(y.shape)
y['Gold-T+14']=values["Gold"].pct_change(periods=-14)
y['Gold-T+22']=values["Gold"].pct_change(periods=-22)
print(y.shape)
y.isna().sum()
# Out:
# (2651, 1)
# (2651, 3)
# Date          0
# Gold-T+14    14
# Gold-T+22    22
# dtype: int64

# %%
# Removing NAs
print(data.shape)
data = data[data['Gold-T-250'].notna()]
y = y[y['Gold-T+22'].notna()]
print(data.shape)
print(y.shape)
# Out:
# (2651, 108)
# (2401, 108)
# (2629, 3)

# %% [markdown]
# Now we will merge the Target variables with the feature space to get a data whcih we can finally start modelling on.

# %%
#Adding Target Variables
data = pd.merge(left=data,right=y,how='inner',on='Date',suffixes=(False,False))
print(data.shape)
data.isna().sum()
# Out:
# (2379, 110)
# Date                           0
# Gold-T-1                       0
# Silver-T-1                     0
# Crude Oil-T-1                  0
# S&P500-T-1                     0
# Russel 2000 Index-T-1          0
# 10 Yr US T-Note futures-T-1    0
# 2 Yr US T-Note Futures-T-1     0
# Platinum-T-1                   0
# Copper-T-1                     0
# Dollar Index-T-1               0
# Volatility Index-T-1           0
# Soybean-T-1                    0
# MSCI EM ETF-T-1                0
# Euro USD-T-1                   0
# Euronext100-T-1                0
# Nasdaq-T-1                     0
# Gold-T-3                       0
# Silver-T-3                     0
# Crude Oil-T-3                  0
# S&P500-T-3                     0
# Russel 2000 Index-T-3          0
# 10 Yr US T-Note futures-T-3    0
# 2 Yr US T-Note Futures-T-3     0
# Platinum-T-3                   0
# Copper-T-3                     0
# Dollar Index-T-3               0
# Volatility Index-T-3           0
# Soybean-T-3                    0
# MSCI EM ETF-T-3                0
#                               ..
# Nasdaq-T-21                    0
# Gold-T-60                      0
# Silver-T-60                    0
# Crude Oil-T-60                 0
# S&P500-T-60                    0
# MSCI EM ETF-T-60               0
# Gold-T-90                      0
# Silver-T-90                    0
# Crude Oil-T-90                 0
# S&P500-T-90                    0
# MSCI EM ETF-T-90               0
# Gold-T-180                     0
# Silver-T-180                   0
# Crude Oil-T-180                0
# S&P500-T-180                   0
# MSCI EM ETF-T-180              0
# Gold-T-250                     0
# Silver-T-250                   0
# Crude Oil-T-250                0
# S&P500-T-250                   0
# MSCI EM ETF-T-250              0
# Gold/15SMA                     0
# Gold/30SMA                     0
# Gold/60SMA                     0
# Gold/90SMA                     0
# Gold/180SMA                    0
# Gold/90EMA                     0
# Gold/180EMA                    0
# Gold-T+14                      0
# Gold-T+22                      0
# Length: 110, dtype: int64

# %%
data.to_csv("Training Data.csv",index=False)

# %%
corr = data.corr().iloc[:,-2:].drop(labels=['Gold-T+14','Gold-T+22'],axis=0)

# %%
import seaborn as sns
import numpy as np

# %%
sns.distplot(corr.iloc[:,0])

# %%
pd.set_option('display.max_rows', None)
corr_data = data.tail(2000).corr()
corr_data = pd.DataFrame(corr_data['Gold-T+14'])
#corr_data = corr_data.iloc[3:,]
corr_data = corr_data.sort_values('Gold-T+14',ascending=False)
#corr_data

# %%
sns.distplot(corr_data)

# %% [markdown]
# # Regression

# %% [markdown]
# ## 22 Day Model

# %%
#data = pd.read_csv("Training Data.csv")

# %%
from pycaret.regression import *

# %%
data_22= data.drop(['Gold-T+14'],axis=1)
data_22.head()
# Out:
#         Date  Gold-T-1  Silver-T-1  Crude Oil-T-1  S&P500-T-1  \
# 0 2010-12-17  0.005984    0.010417       0.003421    0.000805
# 1 2010-12-20  0.005005    0.006873       0.009091    0.002573
# 2 2010-12-21  0.001949    0.003413       0.011261    0.006014
# 3 2010-12-22 -0.001009    0.000000       0.007795    0.003348
# 4 2010-12-23 -0.004903   -0.003401       0.011050   -0.001589
#
#    Russel 2000 Index-T-1  10 Yr US T-Note futures-T-1  \
# 0               0.003734                     0.008306
# 1               0.003592                    -0.000824
# 2               0.010482                    -0.000824
# 3               0.000127                    -0.009901
# 4              -0.002024                    -0.003333
#
#    2 Yr US T-Note Futures-T-1  Platinum-T-1  Copper-T-1  ...  S&P500-T-250  \
# 0                    0.000913      0.001415     0.02439  ...      0.097882
# 1                    0.000000      0.007183     0.00000  ...      0.100706
# 2                   -0.000912      0.006547     0.02381  ...      0.103916
# 3                    0.000000      0.005227     0.00000  ...      0.107027
# 4                    0.000000     -0.004506     0.00000  ...      0.100815
#
#    MSCI EM ETF-T-250  Gold/15SMA  Gold/30SMA  Gold/60SMA  Gold/90SMA  \
# 0           0.092754   -0.008206   -0.001805    0.012638    0.040506
# 1           0.086957   -0.004174    0.003610    0.016601    0.044304
# 2           0.097983   -0.002386    0.006090    0.017567    0.044925
# 3           0.097701   -0.003368    0.005374    0.015569    0.042501
# 4           0.104046   -0.007851    0.001003    0.009699    0.036124
#
#    Gold/180SMA  Gold/90EMA  Gold/180EMA  Gold-T+22
# 0     0.092005    0.035494     0.070472   0.007675
# 1     0.096390    0.039744     0.074871   0.011166
# 2     0.097391    0.040811     0.075992   0.030969
# 3     0.095189    0.038850     0.073962   0.034154
# 4     0.088766    0.032987     0.067834   0.026404
#
# [5 rows x 109 columns]

# %%
a=setup(data_22,target='Gold-T+22',
        ignore_features=['Date'],session_id=11,
        silent=True,profile=False,remove_outliers=False);
        #transformation=True,
        #pca=True,pca_method='kernel',
        #pca_components=10,
        #create_clusters=True,
        #cluster_iter=10,
        #feature_ratio=True,
        #normalize=True,
        #transform_target=True,
       #silent=True);
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_014c8e76_d22c_11ea_b951_c85b76978244" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row0_col1" class="data row0 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row3_col1" class="data row3 col1" >(2379, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row5_col1" class="data row5 col1" >107</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row10_col1" class="data row10 col1" >(2379, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row11_col1" class="data row11 col1" >(1665, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row12_col1" class="data row12 col1" >(714, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_014c8e76_d22c_11ea_b951_c85b76978244level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_014c8e76_d22c_11ea_b951_c85b76978244row18_col1" class="data row18 col1" >None</td>

# %%
compare_models(blacklist=['tr','ard'],turbo=True)
# Out:
# <style  type="text/css" >
#     #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244 th {
#           text-align: left;
#     }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col4 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row10_col0 {
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_5ad4a7d8_d22d_11ea_b6ad_c85b76978244row10_col2 {
#             : ;

# %%
knn_tuned = tune_model('knn',n_iter=150)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0110  0.0002  0.0151  0.8638  0.0127  0.8434
# 1     0.0109  0.0002  0.0147  0.8506  0.0132 -1.3088
# 2     0.0125  0.0004  0.0192  0.8354  0.0157 -0.1468
# 3     0.0109  0.0003  0.0177  0.8344  0.0132 -0.2874
# 4     0.0095  0.0002  0.0123  0.9179  0.0112  0.1777
# 5     0.0108  0.0003  0.0161  0.8700  0.0143 -0.6402
# 6     0.0113  0.0002  0.0155  0.8980  0.0140  0.1331
# 7     0.0129  0.0004  0.0200  0.8459  0.0164  0.1452
# 8     0.0105  0.0002  0.0146  0.8761  0.0126  1.1523
# 9     0.0089  0.0002  0.0124  0.9111  0.0111 -0.6809
# Mean  0.0109  0.0003  0.0158  0.8703  0.0134 -0.0612
# SD    0.0011  0.0001  0.0025  0.0288  0.0016  0.6901

# %%
catb_tuned = tune_model('catboost')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0134  0.0003  0.0175  0.8165  0.0164  0.1837
# 1     0.0123  0.0003  0.0166  0.8093  0.0148 -1.0669
# 2     0.0148  0.0004  0.0200  0.8228  0.0179 -0.3756
# 3     0.0144  0.0004  0.0190  0.8097  0.0175  0.1819
# 4     0.0125  0.0003  0.0169  0.8457  0.0153  0.2127
# 5     0.0130  0.0003  0.0165  0.8640  0.0151 -0.3757
# 6     0.0146  0.0004  0.0198  0.8338  0.0181  0.4370
# 7     0.0155  0.0005  0.0221  0.8124  0.0198 -0.0445
# 8     0.0139  0.0003  0.0182  0.8078  0.0165  0.6634
# 9     0.0121  0.0002  0.0156  0.8594  0.0140 -0.5657
# Mean  0.0137  0.0003  0.0182  0.8281  0.0165 -0.0750
# SD    0.0011  0.0001  0.0019  0.0203  0.0017  0.4929

# %%
et_tuned = tune_model('et')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0154  0.0004  0.0212  0.7332  0.0196  0.1741
# 1     0.0125  0.0003  0.0173  0.7923  0.0159 -0.4140
# 2     0.0166  0.0005  0.0226  0.7733  0.0204 -0.1744
# 3     0.0160  0.0005  0.0213  0.7594  0.0199  1.4198
# 4     0.0130  0.0003  0.0181  0.8227  0.0170 -0.0121
# 5     0.0152  0.0004  0.0211  0.7760  0.0197 -0.4355
# 6     0.0154  0.0005  0.0213  0.8074  0.0196  0.1948
# 7     0.0186  0.0006  0.0250  0.7589  0.0228 -0.0114
# 8     0.0146  0.0004  0.0201  0.7654  0.0185  0.3347
# 9     0.0138  0.0003  0.0185  0.8011  0.0171 -0.6740
# Mean  0.0151  0.0004  0.0206  0.7790  0.0190  0.0402
# SD    0.0017  0.0001  0.0022  0.0255  0.0019  0.5501

# %%
et = create_model('et')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0126  0.0003  0.0174  0.8186  0.0163  0.0918
# 1     0.0101  0.0002  0.0137  0.8699  0.0126 -0.3518
# 2     0.0134  0.0003  0.0183  0.8509  0.0164 -0.0934
# 3     0.0130  0.0003  0.0172  0.8430  0.0158  0.3895
# 4     0.0106  0.0002  0.0142  0.8905  0.0133 -0.0215
# 5     0.0121  0.0003  0.0164  0.8652  0.0151 -0.3854
# 6     0.0130  0.0003  0.0179  0.8638  0.0166  0.2845
# 7     0.0147  0.0004  0.0195  0.8531  0.0178  0.0280
# 8     0.0120  0.0003  0.0163  0.8466  0.0148  0.1858
# 9     0.0108  0.0002  0.0142  0.8830  0.0132 -0.3042
# Mean  0.0122  0.0003  0.0165  0.8585  0.0152 -0.0177
# SD    0.0013  0.0001  0.0018  0.0197  0.0016  0.2544

# %%
evaluate_model(knn_tuned)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(et)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
b=setup(data_22,target='Gold-T+22',
        ignore_features=['Date'],session_id=11,
        silent=True,profile=False,remove_outliers=True);
        #transformation=True,
        #pca=True,pca_method='kernel',
        #pca_components=10,
        #create_clusters=True,
        #cluster_iter=10,
        #feature_ratio=True,
        #normalize=True,
        #transform_target=True,
       #silent=True);
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_be8759cc_d230_11ea_a6cf_c85b76978244row26_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_be8759cc_d230_11ea_a6cf_c85b76978244" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row0_col1" class="data row0 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row3_col1" class="data row3 col1" >(2379, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row5_col1" class="data row5 col1" >107</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row10_col1" class="data row10 col1" >(2260, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row11_col1" class="data row11 col1" >(1581, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row12_col1" class="data row12 col1" >(679, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_be8759cc_d230_11ea_a6cf_c85b76978244level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_be8759cc_d230_11ea_a6cf_c85b76978244row18_col0" class="data row18 col0" >Transformation Method </td>

# %%
knn_tuned = tune_model('knn',n_iter=150)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0095  0.0001  0.0122  0.9179  0.0111  0.0001
# 1     0.0099  0.0002  0.0133  0.9131  0.0116 -0.4384
# 2     0.0119  0.0003  0.0177  0.8462  0.0149  1.6205
# 3     0.0104  0.0003  0.0158  0.8746  0.0146 -0.5026
# 4     0.0108  0.0002  0.0150  0.8690  0.0135  0.0412
# 5     0.0109  0.0002  0.0153  0.8995  0.0129  1.5200
# 6     0.0104  0.0002  0.0150  0.8533  0.0132  0.2961
# 7     0.0104  0.0002  0.0149  0.8931  0.0128 -0.1123
# 8     0.0109  0.0002  0.0148  0.8912  0.0135  0.2784
# 9     0.0104  0.0002  0.0152  0.8706  0.0131 -0.3329
# Mean  0.0105  0.0002  0.0149  0.8829  0.0131  0.2370
# SD    0.0006  0.0000  0.0014  0.0228  0.0011  0.7148

# %%
et = create_model('et')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0119  0.0002  0.0157  0.8640  0.0148  0.0226
# 1     0.0124  0.0003  0.0162  0.8720  0.0151 -0.1737
# 2     0.0121  0.0003  0.0167  0.8625  0.0157  0.9881
# 3     0.0119  0.0003  0.0166  0.8616  0.0155 -0.3287
# 4     0.0119  0.0003  0.0159  0.8528  0.0148 -0.2027
# 5     0.0137  0.0003  0.0185  0.8538  0.0169  0.9315
# 6     0.0112  0.0002  0.0150  0.8536  0.0139  0.1422
# 7     0.0124  0.0003  0.0171  0.8596  0.0154 -0.7069
# 8     0.0120  0.0003  0.0162  0.8707  0.0151  0.2371
# 9     0.0109  0.0002  0.0145  0.8825  0.0135 -0.5205
# Mean  0.0120  0.0003  0.0162  0.8633  0.0151  0.0389
# SD    0.0007  0.0000  0.0011  0.0090  0.0009  0.5344

# %%
catb = create_model('catboost')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0132  0.0003  0.0168  0.8437  0.0154  0.0243
# 1     0.0136  0.0003  0.0176  0.8488  0.0159 -0.7295
# 2     0.0131  0.0003  0.0174  0.8508  0.0163  0.7357
# 3     0.0121  0.0003  0.0172  0.8518  0.0160 -0.3435
# 4     0.0130  0.0003  0.0172  0.8268  0.0156  0.0619
# 5     0.0152  0.0005  0.0216  0.7998  0.0200  1.3780
# 6     0.0122  0.0003  0.0160  0.8325  0.0145  0.5548
# 7     0.0136  0.0003  0.0186  0.8331  0.0165 -0.5204
# 8     0.0137  0.0003  0.0178  0.8438  0.0163  0.3426
# 9     0.0114  0.0002  0.0146  0.8810  0.0131 -1.0034
# Mean  0.0131  0.0003  0.0175  0.8412  0.0160  0.0500
# SD    0.0010  0.0001  0.0017  0.0198  0.0017  0.6908

# %% [markdown]
# ### Ensembling Models

# %%
et_bagged = ensemble_model(et,method='Bagging')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0151  0.0004  0.0197  0.7845  0.0185 -0.0590
# 1     0.0158  0.0004  0.0203  0.7988  0.0190 -0.2431
# 2     0.0155  0.0004  0.0209  0.7847  0.0198  1.1549
# 3     0.0151  0.0005  0.0213  0.7742  0.0199 -0.3261
# 4     0.0142  0.0004  0.0190  0.7896  0.0178 -0.1499
# 5     0.0171  0.0006  0.0238  0.7590  0.0219  0.9159
# 6     0.0135  0.0003  0.0185  0.7758  0.0174  0.0500
# 7     0.0158  0.0005  0.0214  0.7811  0.0194 -0.7455
# 8     0.0153  0.0004  0.0208  0.7858  0.0195  0.2004
# 9     0.0144  0.0003  0.0186  0.8057  0.0173 -0.5150
# Mean  0.0152  0.0004  0.0204  0.7839  0.0191  0.0283
# SD    0.0010  0.0001  0.0015  0.0123  0.0013  0.5674

# %%
knn_tuned_bagged = ensemble_model(knn_tuned, method='Bagging')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0101  0.0002  0.0127  0.9105  0.0117  0.0592
# 1     0.0097  0.0002  0.0127  0.9215  0.0109 -0.2510
# 2     0.0113  0.0002  0.0158  0.8774  0.0133  1.0821
# 3     0.0103  0.0002  0.0142  0.8993  0.0130 -0.4997
# 4     0.0107  0.0002  0.0142  0.8822  0.0127  0.0278
# 5     0.0120  0.0003  0.0165  0.8833  0.0143  1.3020
# 6     0.0109  0.0002  0.0149  0.8556  0.0131  0.4447
# 7     0.0104  0.0003  0.0160  0.8777  0.0137 -0.4285
# 8     0.0111  0.0002  0.0146  0.8946  0.0137  0.3253
# 9     0.0110  0.0003  0.0165  0.8471  0.0137  1.0033
# Mean  0.0107  0.0002  0.0148  0.8849  0.0130  0.3065
# SD    0.0006  0.0000  0.0013  0.0217  0.0010  0.6113

# %% [markdown]
# ### Blending Models

# %%
blend_knn_et = blend_models(estimator_list=[knn_tuned,et])
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0093  0.0001  0.0118  0.9225  0.0111 -0.0192
# 1     0.0099  0.0002  0.0130  0.9182  0.0115 -0.2216
# 2     0.0103  0.0002  0.0149  0.8905  0.0134  0.2452
# 3     0.0099  0.0002  0.0144  0.8965  0.0133 -0.3698
# 4     0.0099  0.0002  0.0133  0.8970  0.0121 -0.1749
# 5     0.0107  0.0002  0.0151  0.9032  0.0132  1.1976
# 6     0.0100  0.0002  0.0133  0.8840  0.0122  0.1125
# 7     0.0101  0.0002  0.0142  0.9033  0.0125 -0.4599
# 8     0.0102  0.0002  0.0137  0.9078  0.0127  0.2769
# 9     0.0096  0.0002  0.0134  0.8996  0.0120 -0.4374
# Mean  0.0100  0.0002  0.0137  0.9022  0.0124  0.0149
# SD    0.0004  0.0000  0.0009  0.0111  0.0007  0.4692

# %%
stack1 = create_stacknet(estimator_list=[[catb,knn_tuned],[et,blend_knn_et]],restack=True)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0087  0.0001  0.0114  0.9274  0.0101  0.0732
# 1     0.0098  0.0002  0.0131  0.9156  0.0118 -0.9316
# 2     0.0114  0.0003  0.0160  0.8743  0.0140  0.9299
# 3     0.0109  0.0003  0.0159  0.8743  0.0148 -0.8293
# 4     0.0103  0.0002  0.0138  0.8880  0.0126 -0.1010
# 5     0.0105  0.0002  0.0147  0.9076  0.0134  1.2207
# 6     0.0098  0.0002  0.0130  0.8891  0.0117  0.4434
# 7     0.0102  0.0002  0.0145  0.8996  0.0127 -0.3116
# 8     0.0105  0.0002  0.0143  0.8984  0.0129  0.3788
# 9     0.0092  0.0002  0.0125  0.9119  0.0111 -0.5221
# Mean  0.0101  0.0002  0.0139  0.8986  0.0125  0.0350
# SD    0.0007  0.0000  0.0014  0.0166  0.0013  0.6800

# %%
stack2 = create_stacknet(estimator_list=[[catb,et,knn_tuned],[blend_knn_et]], restack=True)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0090  0.0001  0.0113  0.9287  0.0104  0.1037
# 1     0.0090  0.0001  0.0119  0.9310  0.0109 -0.6024
# 2     0.0096  0.0002  0.0140  0.9041  0.0128  0.4237
# 3     0.0100  0.0002  0.0140  0.9017  0.0131 -0.8251
# 4     0.0096  0.0002  0.0133  0.8963  0.0122 -0.2636
# 5     0.0095  0.0002  0.0133  0.9246  0.0120  0.9202
# 6     0.0095  0.0002  0.0124  0.8989  0.0112  0.0049
# 7     0.0097  0.0002  0.0138  0.9085  0.0124 -0.4556
# 8     0.0094  0.0002  0.0131  0.9149  0.0120  0.2871
# 9     0.0089  0.0001  0.0114  0.9267  0.0104 -1.1557
# Mean  0.0094  0.0002  0.0129  0.9135  0.0117 -0.1563
# SD    0.0003  0.0000  0.0010  0.0126  0.0009  0.5943

# %%
stack3 = create_stacknet(estimator_list=[[catb,et,knn_tuned],[blend_knn_et]], restack=True,meta_model=blend_knn_et)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0084  0.0001  0.0108  0.9354  0.0100 -0.0706
# 1     0.0089  0.0001  0.0120  0.9299  0.0104 -0.4351
# 2     0.0105  0.0002  0.0151  0.8877  0.0131  0.9928
# 3     0.0095  0.0002  0.0146  0.8934  0.0136 -0.4519
# 4     0.0099  0.0002  0.0137  0.8903  0.0124 -0.1291
# 5     0.0097  0.0002  0.0131  0.9262  0.0116  1.3986
# 6     0.0096  0.0002  0.0132  0.8852  0.0120  0.2291
# 7     0.0101  0.0002  0.0143  0.9019  0.0125 -0.4205
# 8     0.0095  0.0002  0.0127  0.9207  0.0118  0.2870
# 9     0.0090  0.0002  0.0126  0.9108  0.0111 -0.4620
# Mean  0.0095  0.0002  0.0132  0.9081  0.0119  0.0938
# SD    0.0006  0.0000  0.0012  0.0180  0.0011  0.6160

# %%
save_model(model=stack2, model_name='22Day Regressor')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ### 14 Day Model

# %%
data_14= data.drop(['Gold-T+22'],axis=1)
data_14.head()
# Out:
#         Date  Gold-T-1  Silver-T-1  Crude Oil-T-1  S&P500-T-1  \
# 0 2010-12-17  0.005984    0.010417       0.003421    0.000805
# 1 2010-12-20  0.005005    0.006873       0.009091    0.002573
# 2 2010-12-21  0.001949    0.003413       0.011261    0.006014
# 3 2010-12-22 -0.001009    0.000000       0.007795    0.003348
# 4 2010-12-23 -0.004903   -0.003401       0.011050   -0.001589
#
#    Russel 2000 Index-T-1  10 Yr US T-Note futures-T-1  \
# 0               0.003734                     0.008306
# 1               0.003592                    -0.000824
# 2               0.010482                    -0.000824
# 3               0.000127                    -0.009901
# 4              -0.002024                    -0.003333
#
#    2 Yr US T-Note Futures-T-1  Platinum-T-1  Copper-T-1  ...  S&P500-T-250  \
# 0                    0.000913      0.001415     0.02439  ...      0.097882
# 1                    0.000000      0.007183     0.00000  ...      0.100706
# 2                   -0.000912      0.006547     0.02381  ...      0.103916
# 3                    0.000000      0.005227     0.00000  ...      0.107027
# 4                    0.000000     -0.004506     0.00000  ...      0.100815
#
#    MSCI EM ETF-T-250  Gold/15SMA  Gold/30SMA  Gold/60SMA  Gold/90SMA  \
# 0           0.092754   -0.008206   -0.001805    0.012638    0.040506
# 1           0.086957   -0.004174    0.003610    0.016601    0.044304
# 2           0.097983   -0.002386    0.006090    0.017567    0.044925
# 3           0.097701   -0.003368    0.005374    0.015569    0.042501
# 4           0.104046   -0.007851    0.001003    0.009699    0.036124
#
#    Gold/180SMA  Gold/90EMA  Gold/180EMA  Gold-T+14
# 0     0.092005    0.035494     0.070472   0.005250
# 1     0.096390    0.039744     0.074871   0.012422
# 2     0.097391    0.040811     0.075992   0.010555
# 3     0.095189    0.038850     0.073962   0.002023
# 4     0.088766    0.032987     0.067834  -0.004113
#
# [5 rows x 109 columns]

# %%
c=setup(data_14,target='Gold-T+14',
        ignore_features=['Date'],session_id=11,
        silent=True,profile=False,remove_outliers=True);
        #transformation=True,
        #pca=True,pca_method='kernel',
        #pca_components=10,
        #create_clusters=True,
        #cluster_iter=10,
        #feature_ratio=True,
        #normalize=True,
        #transform_target=True,
       #silent=True);
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_bbb18b78_d235_11ea_bf7a_c85b76978244row26_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_bbb18b78_d235_11ea_bf7a_c85b76978244" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row0_col1" class="data row0 col1" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row3_col1" class="data row3 col1" >(2379, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row5_col1" class="data row5 col1" >107</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row10_col1" class="data row10 col1" >(2260, 109)</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row11_col1" class="data row11 col1" >(1581, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row12_col1" class="data row12 col1" >(679, 107)</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_bbb18b78_d235_11ea_bf7a_c85b76978244level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_bbb18b78_d235_11ea_bf7a_c85b76978244row18_col0" class="data row18 col0" >Transformation Method </td>

# %%
compare_models(blacklist=['tr','ard'],turbo=True)
# Out:
# <style  type="text/css" >
#     #T_2cc8520a_d237_11ea_8a98_c85b76978244 th {
#           text-align: left;
#     }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col4 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row10_col0 {
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row10_col1 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98_c85b76978244row10_col2 {
#             : ;
#             text-align:  left;
#         }    #T_2cc8520a_d237_11ea_8a98

# %%
knn_tuned = tune_model('knn',n_iter=150)
catb = create_model('catboost')
et = create_model('et')
knn_tuned_bagged = ensemble_model(knn_tuned, method='Bagging')
blend_knn_et = blend_models(estimator_list=[knn_tuned,et])
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0098  0.0002  0.0124  0.8765  0.0113 -0.1541
# 1     0.0095  0.0002  0.0131  0.8789  0.0121  0.0398
# 2     0.0092  0.0001  0.0119  0.8999  0.0114 -0.2442
# 3     0.0094  0.0002  0.0131  0.8600  0.0109  0.0621
# 4     0.0092  0.0001  0.0121  0.8649  0.0109 -1.7275
# 5     0.0107  0.0002  0.0150  0.8510  0.0133 -0.1407
# 6     0.0097  0.0002  0.0127  0.8422  0.0115  0.0802
# 7     0.0089  0.0001  0.0120  0.8847  0.0110 -0.5602
# 8     0.0089  0.0001  0.0119  0.8775  0.0106  0.1702
# 9     0.0097  0.0002  0.0137  0.8624  0.0123 -0.0499
# Mean  0.0095  0.0002  0.0128  0.8698  0.0115 -0.2524
# SD    0.0005  0.0000  0.0009  0.0161  0.0008  0.5299

# %%
stack1 = create_stacknet(estimator_list=[[catb,knn_tuned],[et,blend_knn_et]],restack=True)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0093  0.0001  0.0120  0.8852  0.0108 -0.1836
# 1     0.0090  0.0002  0.0125  0.8892  0.0113 -0.0698
# 2     0.0083  0.0001  0.0106  0.9205  0.0100 -0.1145
# 3     0.0086  0.0002  0.0126  0.8715  0.0093  0.2632
# 4     0.0093  0.0001  0.0118  0.8700  0.0105 -1.7051
# 5     0.0112  0.0003  0.0160  0.8318  0.0140 -0.1312
# 6     0.0092  0.0001  0.0120  0.8589  0.0107  0.0830
# 7     0.0086  0.0001  0.0118  0.8900  0.0107 -0.2804
# 8     0.0094  0.0002  0.0132  0.8488  0.0116  0.2729
# 9     0.0097  0.0002  0.0134  0.8698  0.0118 -0.1422
# Mean  0.0093  0.0002  0.0126  0.8736  0.0111 -0.2008
# SD    0.0008  0.0000  0.0013  0.0233  0.0012  0.5313

# %%
stack2 = create_stacknet(estimator_list=[[catb,et,knn_tuned],[blend_knn_et]], restack=True)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0091  0.0001  0.0118  0.8884  0.0107 -0.1698
# 1     0.0087  0.0001  0.0117  0.9029  0.0106 -0.0333
# 2     0.0082  0.0001  0.0102  0.9266  0.0097 -0.1948
# 3     0.0086  0.0002  0.0124  0.8744  0.0094  0.2017
# 4     0.0090  0.0001  0.0118  0.8716  0.0106 -1.2429
# 5     0.0105  0.0002  0.0152  0.8483  0.0131 -0.0886
# 6     0.0086  0.0001  0.0113  0.8750  0.0101  0.0658
# 7     0.0086  0.0001  0.0118  0.8890  0.0109 -0.3121
# 8     0.0088  0.0002  0.0127  0.8600  0.0110  0.1264
# 9     0.0089  0.0002  0.0126  0.8844  0.0113 -0.0148
# Mean  0.0089  0.0001  0.0122  0.8821  0.0107 -0.1663
# SD    0.0006  0.0000  0.0012  0.0209  0.0010  0.3877

# %%
stack3 = create_stacknet(estimator_list=[[catb,et,knn_tuned],[blend_knn_et]], restack=True,meta_model=blend_knn_et)
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.0088  0.0001  0.0112  0.8991  0.0101 -0.2117
# 1     0.0086  0.0001  0.0118  0.9013  0.0108  0.1367
# 2     0.0083  0.0001  0.0111  0.9139  0.0105 -0.3552
# 3     0.0089  0.0002  0.0125  0.8731  0.0096  0.1319
# 4     0.0089  0.0001  0.0118  0.8704  0.0104 -2.4908
# 5     0.0103  0.0002  0.0146  0.8603  0.0128 -0.2016
# 6     0.0089  0.0001  0.0120  0.8597  0.0106  0.1354
# 7     0.0082  0.0001  0.0112  0.9003  0.0104 -0.6449
# 8     0.0088  0.0002  0.0126  0.8628  0.0110  0.2267
# 9     0.0091  0.0002  0.0132  0.8731  0.0116 -0.0613
# Mean  0.0089  0.0001  0.0122  0.8814  0.0108 -0.3335
# SD    0.0005  0.0000  0.0010  0.0191  0.0008  0.7635

# %%
save_model(model=stack2, model_name='14Day Regressor')
# Out:
# Transformation Pipeline and Model Succesfully Saved
